# %%
import re
import csv
import time

delay = 2

def admin():
    while True:
        print("Admin Menu:")
        print("1. View User Registrations")
        print("2. Edit User Accounts")
        print("3. View Logs")
        print("4. View and Edit Available Services")
        print("5. Exit Admin Menu")
        option = input("Enter your choice: ")
        if option == "1":
            view_user_registrations()
            return
        elif option == "2":
            edit_user_accounts()
            return
        elif option == "3":
            view_logs()
            return
        elif option == "4":
            view_and_edit_services()
            return
        elif option == "5":
            print("Exiting Admin Menu and Returning to normal menu.")
            Main()
            return
        else:
            print("Invalid option. Please try again.")

def view_and_edit_services():
    while True:
        print()
        print("View and Edit Available Services:")
        print("1. View Room Booking Details")
        print("2. Edit Details")
        print("3. Exit")
        option = input("Enter your choice: ")
        if option == "1":
            with open('Booking-Details.csv', 'r') as booking_file:
                booking_reader = list(csv.reader(booking_file))
                for i in booking_reader:
                    print(i)
                time.sleep(45)
        elif option == "2":
            row1=[]
            with open('Booking-Details.csv', 'r') as booking_file:
                booking_reader = csv.reader(booking_file)
                for rows in booking_reader:
                    print(rows)
                    row1.append(rows)
                while True:
                    x=input("Enter at which line you want to edit:")
                    if x.isdigit() and (int(x)-1)<len(row1):
                        a=row1[int(x)-1][1]
                        b=row1[int(x)-1][2]
                        row=[]
                        with open('Rooms.csv', 'r') as rooms_file:
                            rooms_reader = csv.reader(rooms_file)
                            for rows in rooms_reader:
                                row.append(rows)
                            for i in row:
                                if i[0]==a and i[1]==b:
                                    i[5]=str(int(i[5])+1)
                        with open('Rooms.csv', 'w',newline="") as rooms_file:
                            writer=csv.writer(rooms_file)
                            writer.writerows(row)
                        print("Why do you want to edit this line?")
                        print("1. Cancellation")
                        print("2. Checked Out")
                        print("3. Room Change")
                        y=input("Enter your choice:")
                        if y=='1' or y=='2':
                            row1.pop(int(x)-1)
                            with open('Booking-Details.csv', 'w',newline="") as booking_file:
                                writer=csv.writer(row1)
                                writer.writerows(row1)
                            print("Editing Completed!")
                            break
                        elif y=="3":
                            row1.pop(int(x)-1)
                            with open('Booking-Details.csv', 'w',newline="") as booking_file:
                                writer=csv.writer(booking_file)
                                writer.writerows(row1)
                            rooms()
                            return
                        else:
                            print("Invalid Option!")
                    else:
                        print("The line you entered does not exist!\nDo you want to edit or go back?")
                        while True:
                            o=input("Enter y/n:")
                            if o=='y':
                                print("Editing Line...")
                                break
                            elif o=='n':
                                print("Returning to Admin Menu...")
                                return
                            else:
                                print("Invalid Option!")
        elif option == "3":
            print("Exiting Edit Menu and Returning to Admin menu.")
            admin()
            return
        else:
            print("Invalid Option! Please try again.")

def edit_user_accounts():
    x=input("Enter the Username of the person you want to edit:")
    while True:
        print("Edit User Accounts:")
        print("1. Edit User First Name")
        print("2. Edit User Last Name")
        print("3. Edit User Username")
        print("4. Edit User Password")
        print("5. Edit User Phone Number")
        print("6. Edit User Email")
        print("7. Exit")
        option = input("Enter your choice: ")
        if option == "1" or "2" or "3" or "4" or "5" or "6":
            row=[]
            with open('User-Details.csv', 'r') as read_file:
                file_reader = csv.reader(read_file)
                for i in file_reader:
                    row.append(i)
                for i in range(len(row)):
                    if row[i][2] == x:
                            row[i][option]=input("Enter New:")
            with open('User-Details.csv', 'w',newline="") as edit_file:
                writer=csv.writer(edit_file)
                writer.writerows(row)
        elif option == "7":
            print("Exiting Edit Menu and Returning to Admin menu.")
            admin()
            return
        else:
            print("Invalid Option!")

def view_user_registrations():
    with open('User-Details.csv', 'r') as registration_file:
        registration_reader = csv.reader(registration_file)
        for i in registration_reader:
            print(i)
    time.sleep(0)
    while True:
        print('Do you want to edit anything in this file?(If no, you will be redirected to Admin page.).')
        x=input("Enter y/n:")
        if x=='y':
            edit_user_accounts()
            return
        elif x=='n':
            admin()
            return
        else:
            print("Invalid option. Please try again.")

def view_logs():
    with open('Login.csv', 'r') as login_file:
        login_reader = list(csv.reader(login_file))
        for i in login_reader:
            print(i)
    time.sleep(20)
    print('Do you want to go back to the Admin Page?')
    x=input("Enter y/n:")
    if x=='y':
        admin()
        return
    else:
        Main()
        return

def Delay(n):
    delay1=0.01
    for i in n:
        print(i,end="",flush=True)
        time.sleep(delay1)
    return

def error():
    print("Have you registered?\n1.Yes\n2.No")
    while True:
        Option = input("Your Option: ")
        if Option == '1':
            print("Forgot Password?\n1.yes\n2.no")
            while True:
                y=input("Your Option: ")
                if y=='1':
                    time.sleep(delay)
                    forgot()
                    return
                elif y=='2':
                    print("Try Again.")
                    time.sleep(delay)
                    login()
                    return
                else:
                    print("Invalid Option!")
        elif Option == '2':
            print("You have to register first!\n")
            time.sleep(delay)
            register()
            return
        else:
            print("Invalid Option! Choose 1 or 2")

def login():
    with open('User-pw.csv', 'r') as registration_file:
        registration_reader = csv.reader(registration_file)
        rows=list(registration_reader)
        k=0
        while True:
            global Username1
            Username1 = input("Enter Username:")
            Password = input('Password:')
            for i in range(len(rows)):
                if rows[i][0] == Username1 and rows[i][1] == Password:
                    if Username1=="AranthAdmin" and Password=="Mrblue@123":
                        print("\nRedirecting to admin...")
                        with open('Login.csv', 'a', newline="\n") as Login_file:
                            writer = csv.writer(Login_file)
                            writer.writerow([Username1,time.strftime("%H:%M:%S"),time.strftime("%d:%m:%Y")])
                            Login_file.close()                        
                        time.sleep(delay)
                        admin()
                        return
                    else:
                        print('Login Complete!\n')
                        with open('Login.csv', 'a', newline="\n") as Login_file:
                            writer = csv.writer(Login_file)
                            writer.writerow([Username1,time.strftime("%H:%M:%S"),time.strftime("%d:%m:%Y")])
                            Login_file.close()
                        time.sleep(delay)
                        services()
                        return
            else:
                k+=1
                print("Invalid Username or Password!")
                if k>=2:
                    time.sleep(delay)
                    error()
                    return

def forgot():
    Username = input("Enter Your Username:")
    Email=input("Enter Your Email:").lower()
    with open('User-Details.csv', 'r') as registration_file:
        registration_reader = list(csv.reader(registration_file))
        k=0
        for i in range(len(registration_reader)):
            k+=1
            if registration_reader[i][2] == Username and registration_reader[i][5] == Email:
                print(registration_reader[i][3],"is your PASSWORD\n")
                time.sleep(delay)
                Main()
                return
        else:
            print("Invalid Username or Email!")

def register():
    First_Name = input("Enter Your First Name:")
    Last_Name = input("Enter Your Last Name:")
    while True:
        Username = input("Enter Your Username:")
        if re.match(r'^[a-zA-Z0-9]+$', Username) and 4<len(Username)<=20:
            with open('User-pw.csv', 'r') as Check_file:
                Check_reader = list(csv.reader(Check_file))
                k=0
                for i in range(len(Check_reader)):
                    if Check_reader[i][0] == Username:
                        print("Username already exists!Try again!")
                        k=1
                if k==0:
                    print("Username is valid and going to be saved...")
                    break
    while True:
        Ph_Number = input("Enter Your Mobile Number:+91 ")
        if re.match(r'^\d{10}$', Ph_Number):
            print("Your 10 Digit Phone Number will receive any updates about our Resort...")
            print("Are You Sure?")
            x=input("y/n:")
            if x=='y':
                print("Saved")
                break
            else:
                print("Ok. Try Again.")
        else:
            print("Invalid Phone Number!")
    while True:
        Email = input("Enter Your Email:").lower()
        if re.match(r'^[a-zA-Z0-9]+@[a-zA-Z]+\.[com]{3}$', Email):
            print("Your Email is going to receive any updates about our Resort...")
            print("Are You Sure?")
            x=input("y/n:")
            if x=='y':
                print("Saved")
                break
            else:
                print("Ok. Try Again.")
        else:
            print("Invalid Email!")
    while True:
        Password = input("Enter Your Password:")
        Confirmation = input("Confirm Your Password:")
        if len(Password) < 8:
            print("Password must be at least 8 characters long!")
        elif Password == Confirmation:
            if re.search(r'\d+', Password) and re.search(r'[A-Z]', Password) and re.search(r'[a-z]', Password) and re.search(r'[!@#$%^&*]', Password):
                with open('User-pw.csv', 'a', newline="\n") as registration_file:
                    writer = csv.writer(registration_file)
                    writer.writerow([Username,Password])
                    registration_file.close()
                with open('User-Details.csv', 'a', newline="\n") as registration_file:
                    writer = csv.writer(registration_file)
                    writer.writerow([First_Name,Last_Name,Username,Password,Ph_Number,Email])
                    registration_file.close()
                    print("Registration Successful!\n")
                    time.sleep(delay)
                    services()
                    return
            else:
                print("Password must contain at least one number, one uppercase letter, one lowercase letter, and one special character!")
        else:
            print("Passwords do not match!")

def Main():
    with open('Resort Desc.txt', 'r') as desc_file:
        Description = desc_file.read()
        Delay(Description)
    while True:
        Option1 = input("Your Option: ")
        time.sleep(delay)
        if Option1 == '1':
            print("\nRedirected to login page!")
            login()
            return
        elif Option1 == '2':
            print("\nRedirected to register page!")
            register()
            return
        elif Option1 == '3':
            print("Redirecting to About Us Page...\n")
            aboutUs()
            return
        elif Option1 == '4':
            print("Redirecting to Contact Us Page...\n")
            contactUs()
            return
        elif Option1 == '5':
            print("Thank You for Using BlueWaves Resort!")
            return
        else:
            print("Option Doesn't Exist!")

def vacancy(m,n):
    rows = []
    with open('Rooms.csv', 'r') as rooms_file:
        rooms_reader = csv.reader(rooms_file)
        for row in rooms_reader:
            rows.append(row)
    for i in range(len(rows)):
        if rows[i][0] == str(m) and rows[i][1] == str(n):
            if rows[i][5] == '0':
                print("No rooms are available.\nSorry for the inconvenience.")
                return 0
            else:
                print("Your Booking has been confirmed!")
                rows[i][5] = str(int(rows[i][5]) - 1)
                break
    with open('Rooms.csv', 'w', newline='') as rooms_file:
        writer = csv.writer(rooms_file)
        writer.writerows(rows)
    return 1

def rooms():
    print()
    c=0
    with open('AC Rooms.txt','r') as ac_file:
        ac_reader=ac_file.read()
        Delay(ac_reader)
    with open('NON AC Rooms.txt','r') as nonac_file:
        nonac_reader=nonac_file.read()
        Delay(nonac_reader)
    a=int(input('\n\nWhat types of room would you like to book?\n1.A/C Room\n2.Non A/C Room\nYour Option:'))
    if a==1:
        total=0
        while True:
            b=input('Which room would you like to book?(Enter option):')
            if b=='1':
                c=c+1500
                break
            elif b=='2':
                c=c+2500
                break
            elif b=='3':
                c=c+3200
                break
            elif b=='4':
                c=c+4400
                break
            elif b=='5':
                c=c+6000
                break
            else:
                print('Invalid Option!')
        n=int(input('How many nights would you like to book your room for:'))
        Check_in=input("Enter check in date in this format (dd/mm/yyyy)")
        Check_out=input("Enter check out date in this format (dd/mm/yyyy)")
        print('Your amount is:',n*c)
        if 2500>c>=1000:
            print('GST and other taxes:',(n*c)*(12/100))
            total+=(n*c)+(n*c)*(12/100)
            print('Total amount:',total)
        elif 2500<=c<7500:
            print('GST and other taxes:',(n*c)*(18/100))
            total+=(n*c)+(n*c)*(18/100)
            print('Total amount:',total)
        while True:
            print('\nWould you like to confirm your booking?')
            e=input('y/n:')
            if e=='y':
                vacant=vacancy(a,b)
                if vacant==0:
                    time.sleep(delay)
                    rooms()
                    return
                else:
                    print("You can make payment at the hotel after your arrival\nThank you for choosing us!")
                    if Username1=="AranthAdmin":
                        Username11=input("Enter the Username:")
                        with open('Booking-Details.csv','a',newline='') as booking_file:
                            writer = csv.writer(booking_file)
                            writer.writerow([Username11,a,b,n,Check_in,Check_out,total])
                            booking_file.close()
                        view_and_edit_services()
                        return
                    else:
                        with open('Booking-Details.csv','a',newline='') as booking_file:
                            writer = csv.writer(booking_file)
                            writer.writerow([Username1,a,b,n,Check_in,Check_out,total])
                            booking_file.close()
                    print()
                    while True:
                        print('Would you like to return back to our services page?')
                        g=input('y/n:')
                        time.sleep(delay)
                        if g=='y':
                            print("Redirecting to service page...\n")
                            services()
                            return
                        elif g=='n':
                            print('Thank you for choosing us!\n')
                            Main()
                            return
                        else:
                            print('Invalid Option!')
            elif e=='n':
                while True:
                    print('Would you like to make a different booking?')
                    f=input('y/n:')
                    if f=='y':
                        time.sleep(delay)
                        rooms()
                        return
                    elif f=='n':
                        while True:
                            print('Would you like to return back to our services page?')
                            g=input('y/n:')
                            time.sleep(delay)
                            if g=='y':
                                print("Redirecting to service page...\n")
                                services()
                                return
                            elif g=='n':
                                print('Thank you for choosing us!\n')
                                Main()
                                return
                            else:
                                print("Invalid Option!")
                    else:
                        print('Invalid Option!')
            else:
                print('Invalid Option!')  
    elif a==2:
        total=0
        while True:
            b=int(input('Which room would you like to book?(Enter option):'))
            if b==1:
                c=c+500
                break
            elif b==2:
                c=c+900
                break
            else:
                print('Invalid Option!')
        n=int(input('How many nights would you like to book your room for:'))
        print('Your amount is:',n*c)
        print('GST and other taxes:',(n*c)*(0/100))
        total+=(n*c)+(n*c)*(0/100)
        print('Total amount:',total)
        while True:
            print('Would you like to confirm your booking?')
            e=input('y/n:')
            if e=='y':
                vacant=vacancy(a,b)
                if vacant==0:
                    time.sleep(delay)
                    rooms()
                    return
                else:
                    print("You can make payment at the hotel after your arrival\nThank you for choosing us!")
                    if Username1=="AranthAdmin":
                        Username11=input("Enter the Username:")
                        with open('Booking-Details.csv','a',newline='') as booking_file:
                            writer = csv.writer(booking_file)
                            writer.writerow([Username11,a,b,n,total])
                            booking_file.close()
                    else:
                        with open('Booking-Details.csv','a',newline='') as booking_file:
                            writer = csv.writer(booking_file)
                            writer.writerow([Username1,a,b,n,total])
                            booking_file.close()
                    print()
                    while True:
                        print('Would you like to return back to our services page?')
                        g=input('y/n:')
                        time.sleep(delay)
                        if g=='y':
                            print("Redirecting to service page...\n")
                            services()
                            return
                        elif g=='n':
                            print('Thank you for choosing us!\n')
                            Main()
                            return
                        else:
                            print('Invalid Option!')
            elif e=='n':
                while True:
                    print('Would you like to make a different booking?')
                    f=input('y/n:')
                    if f=='y':
                        time.sleep(delay)
                        rooms()
                        return
                    elif f=='n':
                        while True:
                            print('Would you like to return back to our services page?')
                            g=input('y/n:')
                            time.sleep(delay)
                            if g=='y':
                                print("Redirecting to service page...\n")
                                services()
                                return
                            elif g=='n':
                                print('Thank you for choosing us!\n')
                                Main()
                                return
                            else:
                                print("Invalid Option!")
                    else:
                        print('Invalid Option!')
            else:
                print('Invalid Option!')
    else:
        rooms()
        return

def aboutUs():
    with open ('AboutUs.txt','r') as about_file:
        r = about_file.read()
        Delay(r)
    x="Do you want to go back to our Main page?\n1.Yes\n2.No\n"
    Delay(x)
    y=input('Your Option:')
    if y=='1':
        print("Redirecting to service page...\n")
        time.sleep(delay)
        services()
        return
    elif y=='2':
        print("Redirecting to our menu page...\n")
        time.sleep(delay)
        print("Thank you for Visiting our page!\n")
        return
    else:
        print('Invalid Option!')

def contactUs():
    with open('ContactUs.txt','r') as contact_file:
        r = contact_file.read()
        Delay(r)
    x="\nDo you want to go back to our Main page?\n1.Yes\n2.No\n"
    Delay(x)
    y=input('Your Option:')
    time.sleep(delay)
    if y=='1':
        print("Redirecting to service page...\n")
        Main()
        return
    elif y=='2':
        print("Thank you for visiting our page!\n")
        return

def convention():
    with open('conventionHall.txt','r') as convention_file:
        convention_reader=convention_file.read()
        Delay(convention_reader)
    with open('ContactUs.txt','r') as contactus_file:
        contactus_reader=contactus_file.read()
        Delay(contactus_reader)
    time.sleep(5)
    print('Would you like to return back to our services page?')
    g=input('y/n')
    if g=='y':
        services()
        return  
    else:
        print('Thank you for visiting us!')
        Main()
        return

def spa():
    with open('spa.txt','r') as spa_file:
        spa_reader=spa_file.read()
        Delay(spa_reader)
    with open('ContactUs.txt','r') as contactus_file:
        contactus_reader=contactus_file.read()
        Delay(contactus_reader)
    time.sleep(5)
    print('Would you like to return back to our services page?')
    g=input('y/n')
    if g=='y':
        services()
        return
    else:
        print('Thank you for visiting us!')
        Main()
        return

def swimmingPool():
    with open('swimmingPool.txt','r') as swim_file:
        swim_reader=swim_file.read()
        Delay(swim_reader)
    with open('ContactUs.txt','r') as contactus_file:
        contactus_reader=contactus_file.read()
        Delay(contactus_reader)
    time.sleep(5)
    print('Would you like to return back to our services page?')
    g=input('y/n')
    if g=='y':
        services()
        return
    else:
        print('Thank you for visiting us!')
        Main()
        return
    
def review():
    print('Our previous reviews:')
    with open('review.csv','r') as review_file:
        field_names=['Username:','Rating:','Feedback/Comment:']
        review_reader=csv.DictReader(review_file,fieldnames=field_names,delimiter='|')
        for n,line in enumerate(review_reader):
            print('%d.'%(n+1))
            for j,i in enumerate(line):
                print(field_names[j],line[i])
    print('Would you like to add a review with your username:',Username1)
    k=input('Enter y/n:')
    if k=='y':
        print('What rating would u give us out of 5')
        r=input('_ star:')
        r=r+'star'
        comment=input('Please add additional comment/feedback:')
        with open('review.csv','a') as review_file:
            review_writer=review_file.write(Username1+','+r+','+comment)
        print('Your response has been recorded.')
        print('Thank you for your valuable feedback!')
        print('Would you like to return back to our services page?')
        g=input('Enter y/n:')
        if g=='y':
            services()     
        else:
            print('Thank you for visiting us!')
            return 
    else:
        print('Would you like to return back to our services page?')
        g=input('Enter y/n:')
        if g=='y':
            services()     
        else:
            print('Thank you for visiting us!')
            return 
    print('Would you like to return back to our services page?')
    g=input('Enter y/n:')
    if g=='y':
        services()     
    else:
        print('Thank you for visiting us!')
    return

def menu():
    with open('menu.txt','r') as menu_txt:
        m=menu_txt.read()
        Delay(m)
        print('\n\n')
    time.sleep(1)
    s=0
    #print('1.press b for break fast \n2.press l for lunch \n3.press d for dinner\npress 0 to return to main menu')
    while True:
        print('1.press b for break fast \n2.press l for lunch \n3.press d for dinner\npress 0 to return to main menu')
        a=input('Please select your option\n')
        if a=='b':
            with open('breakfast.txt','r') as breakfast_file:
                bf=breakfast_file.read()    
                print(bf)
            print('Select your favourite breakfast:')
            while True:
                b=input()
                if b=='1':
                    s+=30
                elif b=='2':
                    s+=50
                elif b=='3':
                    s+=60
                elif b=='4':
                    s+=80
                elif b=='5':
                    s+=40
                elif b=='6':
                    s+=50
                elif b=='7':
                    s+=80
                elif b=='8':
                    s+=65 
                elif b=='9':
                    s+=75
                elif b=='0':
                    break
                else:
                    print('Please ensure you give a correct number to order')
            print('Would you like to have coffee or tea')
            print('press y to order\npress n to return')
            x=input()
            if x=='y':
                print('press 1 for coffee\npress 2 for tea\npress 3 for milk\npress 0 to exit')
                while True:
                    z=input()
                    if z=='1':
                        w=int(input('Enter number of coffees:'))
                        s+=w*20
                    elif z=='2':
                        w=int(input('Enter number of teas:'))
                        s+=15*w
                    elif z=='3':
                        w=int(input('Enter number of milk orders'))
                        s+=10*w
                    elif z=='0':
                        break
                    else:print('Please enter a valid input')
        elif a=='l':
            d=1
            with open('lunch.txt','r') as lunch_txt:
                l=lunch_txt.read()
                print(l)
            print('Enter your favourite dish:')
            while True:
                c=input('Select your dish\n')
                if c=='1':
                    s+=200
                elif c=='2':
                    s+=200
                elif c=='3':
                    x=input('Please enter number of rotis:')
                    s+=d*30
                elif c=='4':
                    s+=210
                elif c=='5':
                    s+=180
                elif c=='6':
                    s+=190
                elif c=='7':
                    s+=300
                elif c=='8':
                    s+=250
                elif c=='9':
                    s+=200
                elif c=='10':
                    s+=160
                elif c=='11':
                    s+=260
                elif c=='0':
                    break
                else:print('Please enter a valid input')
            print('Would you like add deserts to your order for the best experience')
            with open('desert.txt','r') as desert_txt:
                d=desert_txt.read()
                print(d)
            print('press y if yes\npress n if no')
            v=input()
            if v=='y':
                print('Please order your favourite desert')
                while True:
                    x=input()
                    if x=='1':
                        s+=40
                    elif x=='2':
                        s+=35
                    elif x=='3':
                        s+=40
                    elif x=='4':
                        s+=40
                    elif x=='5':
                        s+=45
                    elif x=='0':
                        break
                    else:
                        print('Please enter a valid input')      
            elif v=='n':
                print('Hope you try our desert for the next time')
            else:print('please enter a valid input') 
        elif a=='d':  
            l=1
            with open('lunch.txt','r') as dinner_txt:
                d=dinner_txt.read()
                print(d)
            print('Enter your favourate dish:')
            while True:
                c=input('Select your dish\n')
                if c=='1':
                    s+=200
                elif c=='2':
                    s+=200
                elif c=='3':
                    x=int(input('Please enter number of rotis:\n'))
                    s+=l*30
                elif c=='4':
                    s+=210
                elif c=='5':
                    s+=180
                elif c=='6':
                    s+=190
                elif c=='7':
                    s+=300
                elif c=='8':
                    s+=250
                elif c=='9':
                    s+=200
                elif c=='10':
                    s+=160
                elif c=='11':
                    s+=260
                elif c=='0':
                    break
                else:print('Please enter a valid input')
            print('Would you like add deserts to your order for a better experience') 
            with open('desert.txt','r') as desert_txt:
                d=desert_txt.read()
                print(d)
            #print('Would you like to have desert with your dinner for a better experience')
            print('press y for yes\npress n for no')
            c=input()
            if c=='y':
                print('Please order your favourite desert')
                while True:
                    x=input()
                    if x=='1':
                        s+=40
                    elif x=='2':
                        s+=35
                    elif x=='3':
                        s+=40
                    elif x=='4':
                        s+=40
                    elif x=='5':
                        s+=45
                    elif x=='0':
                        break
                    else:
                        print('Please enter a valid input')               
            elif c=='0':
                print('Hope you order desert next time')
                break
            else:print('Please enter a valid input')
        elif a=='0':
            print('Thank you for visiting!')
            break
        else:
            print('PLease enter a valid input')
    v=s*0.04
    print('Food cost:',s)
    print('GTS and other taxes: %.2f'%v)
    print('Total Amount:',s+v)
    print('You can pay the amount after delivery')
    print('Would you like to return back to our services page?')
    g=input('y/n')
    if g=='y':
        services()     
    else:
        print('Thank you for visiting!')
    return
        
def services():
    print('What services of ours would you like to avail?')
    print('1.Book a hotel room\n2.Order food\n3.Know more about our Banquet Hall\n4.Know more about our Spa\n5.Know more about our Swimming pool\n6.Reviews and Feedback\n7.Log out')
    while True:
        option=input('Choose an option:')
        if option=='1':
            rooms()
            return
        elif option=='2':
            menu()
            return
        elif option=='3':
            convention()
            return
        elif option=='4':
            spa()
            return
        elif option=='5':
            swimmingPool()
            return
        elif option=='6':
            review()
            return
        elif option=='7':
            Main()
            return
        else:
            print('Invalid Option!')

Main()
